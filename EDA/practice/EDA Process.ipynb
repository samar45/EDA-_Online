# %% [markdown]
# ### step -1
# - Read the data
#
# ### step -2
# - Data quick checks
#       - info ,shape, size , missing values ,columns  ,dtypes
#
# ### step -3
#  - conver catagorical columns numerical columns  names separately
#
# ### Step -4
# -  you nedd to fill the missing values
#
# ### step -5
# -  cata goriacl data nalysis
#     - unique
#     - nunique
#     - value counts
#     - bar chart
#     - count plot
#     - pei chart
#
# ### step -6
#
# -  Numeraical data anlysis
#      - describe
#      - histogram (data skewness)
#      - daat skewens
#
# ### step - 7
# - outlaires analysis
#       - Box plot creation
#
# ### step -8
#    - Data  transformation
#
# ### step -9
#    - Encodeing mwthord
#    - map
#    - label encoder
#    - one hot encoder
#
# ### step - 10
#
#      - scaling mwthods
#      - z score (standardization)
#      - min -max scaling (normalization)
#
#
# Columns also called ===  faetures === variables
# columns are two tyeps
# input columns        output columns
# indepent               depenednt colulmns
#                         Traget columns
#
# ===============================================
#
#
# rows  ===  fields === instances === tupels
# values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### step -1

# %%
bank_df = pd.read_csv(r"C:\Users\SAMAR\PycharmProjects\Naresh IT\Classroom\Python seassons\data files\bank.csv",sep=";")
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ### step -2

# %%
path = r"C:\Users\SAMAR\PycharmProjects\Naresh IT\Classroom\Python seassons\data files\loan predictor.csv"
with open(path) as file:
    print(file.read())
# Out:
# Loan_ID,Gender,Married,Dependents,Education,Self_Employed,ApplicantIncome,CoapplicantIncome,LoanAmount,Loan_Amount_Term,Credit_History,Property_Area,Loan_Status
# LP001002,Male,No,0,Graduate,No,5849,0,,360,1,Urban,Y
# LP001003,Male,Yes,1,Graduate,No,4583,1508,128,360,1,Rural,N
# LP001005,Male,Yes,0,Graduate,Yes,3000,0,66,360,1,Urban,Y
# LP001006,Male,Yes,0,Not Graduate,No,2583,2358,120,360,1,Urban,Y
# LP001008,Male,No,0,Graduate,No,6000,0,141,360,1,Urban,Y
# LP001011,Male,Yes,2,Graduate,Yes,5417,4196,267,360,1,Urban,Y
# LP001013,Male,Yes,0,Not Graduate,No,2333,1516,95,360,1,Urban,Y
# LP001014,Male,Yes,3+,Graduate,No,3036,2504,158,360,0,Semiurban,N
# LP001018,Male,Yes,2,Graduate,No,4006,1526,168,360,1,Urban,Y
# LP001020,Male,Yes,1,Graduate,No,12841,10968,349,360,1,Semiurban,N
# LP001024,Male,Yes,2,Graduate,No,3200,700,70,360,1,Urban,Y
# LP001027,Male,Yes,2,Graduate,,2500,1840,109,360,1,Urban,Y
# LP001028,Male,Yes,2,Graduate,No,3073,8106,200,360,1,Urban,Y
# ...

# %%
r"C:\Users\SAMAR\PycharmProjects\Naresh IT\Classroom\Python seassons\data files\loan predictor.csv"
df = pd.read_csv(r"C:\Users\SAMAR\PycharmProjects\Naresh IT\Classroom\Python seassons\data files\loan predictor.csv")
df.sample(3)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 423  LP002362    Male     Yes          1  Graduate            No
# 223  LP001749    Male     Yes          0  Graduate            No
# 210  LP001708  Female      No          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 423             7250             1667.0       110.0               NaN
# 223             7578             1010.0       175.0               NaN
# 210            10000                0.0       214.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 423             0.0         Urban           N
# 223             1.0     Semiurban           Y
# 210             1.0     Semiurban           N
